# %%
import json

# %%
with open("gsm8k/gpt-4o-mini/results_calibrated.json", "r") as f:
    data = json.load(f)
data["confidences"]
# Out:
# [95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  90.0,
#  100.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  100.0,
#  95.0,
#  95.0,
#  95.0,
#  100.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  100.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  90.0,
#  100.0,
#  95.0,
#  100.0,
#  100.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
# ...

# %%
data["preds"]
# Out:
# ['18',
#  '3',
#  '70,000',
#  '540',
#  '20',
#  '$40',
#  '260',
#  '120',
#  '165 miles',
#  '460',
#  '366',
#  '694',
#  '12',
#  '18',
#  '60',
#  '125',
#  '230',
#  '57500',
#  '7',
#  '6',
#  'The amount of water in the remaining 24 liters is 15.67 liters.',
#  '14',
#  '7',
#  '8',
#  '26.00',
#  '2',
#  '243.00',
#  '16.00',
#  '25',
#  '104',
#  '109',
#  '80',
#  '35',
#  '70',
#  '23',
#  '9',
#  '75.00',
#  '0',
#  '10',
#  '26',
#  '8',
#  '200',
#  '26',
#  '48',
#  '20',
#  '104',
#  '163',
#  'The total amount John spent on ties is 800.',
#  '8',
#  '30',
#  '294',
#  '5.',
#  '15',
#  '40',
#  '40',
#  '14',
#  '3',
#  '83',
#  '57.00',
#  '187',
#  '17',
#  '1430',
#  '$25,000',
#  'Total amount paid: 1,596.',
#  '300',
#  '36',
#  '48',
#  '595',
#  '36',
#  '60',
#  '7425',
#  '60',
#  '221',
#  '255',
#  '88.00',
#  '7.5',
#  '5',
#  '100',
#  '6',
#  '70',
#  '10',
#  '17',
#  '623',
#  '600',
#  '15',
#  '44',
#  '22',
#  'The answer is 10548.',
#  '8000',
# ...

# %%
data["answers"]
# Out:
# ['18',
#  '3',
#  '70000',
#  '540',
#  '20',
#  '64',
#  '260',
#  '160',
#  '45',
#  '460',
#  '366',
#  '694',
#  '13',
#  '18',
#  '60',
#  '125',
#  '230',
#  '57500',
#  '7',
#  '6',
#  '15',
#  '14',
#  '7',
#  '8',
#  '26',
#  '2',
#  '243',
#  '16',
#  '25',
#  '104',
#  '109',
#  '80',
#  '35',
#  '70',
#  '23',
#  '9',
#  '75',
#  '2',
#  '10',
#  '18',
#  '8',
#  '200',
#  '26',
#  '48',
#  '20',
#  '104',
#  '163',
#  '800',
#  '8',
#  '30',
#  '294',
#  '5',
#  '15',
#  '40',
#  '40',
#  '14',
#  '3',
#  '83',
#  '57',
#  '187',
#  '17',
#  '1430',
#  '25000',
#  '1596',
#  '300',
#  '36',
#  '48',
#  '595',
#  '36',
#  '60',
#  '7425',
#  '60',
#  '221',
#  '255',
#  '88',
#  '60',
#  '5',
#  '100',
#  '6',
#  '70',
#  '10',
#  '17',
#  '623',
#  '600',
#  '15',
#  '44',
#  '22',
#  '9360',
#  '8000',
#  '24',
#  '225',
#  '28',
#  '4',
#  '36',
#  '348',
#  '40',
#  '3',
#  '12',
#  '5',
#  '58',
#  '175',
#  '6',
#  '26',
#  '140',
#  '500',
#  '20',
#  '72',
# ...

# %%
import sys

sys.path.append("..")
from utils import gsm_judge

# %%
gsm_judge(data["preds"][0], data["answers"][0])
# Out:
# True
